# %% [markdown]
# Read the contents of your last exercise file into a variable.

# %%
with open('4.6_import_exercises.py') as f:
    contents = f.read()

# %%
# solution from class
filename = '4.6_import_exercises.py'

with open(filename, 'r') as f:
    contents = f.readlines()
    for i, line in enumerate(contents, 1):
        print(i, ':', line)
# Out:
# 1 : #!/usr/bin/env python
#
# 2 : # coding: utf-8
#
# 3 :
#
# 4 : # 1. Import and test 3 of the functions from your functions exercise file.
#
# 5 : #
#
# 6 : # -- Your functions exercise are not currently in a file with a name that can be easily imported. Copy your functions exercise file and name the copy functions_exercises.py.
#
# 7 : #
#
# 8 : # -- Import each function in a different way:
#
# 9 : #
#
# 10 : # -- import the module and refer to the function with the . syntax
#
# 11 :
#
# 12 : # In[1]:
#
# 13 :
#
# 14 :
#
# 15 : import function_exercises
#
# 16 :
#
# 17 :
#
# 18 : # In[2]:
#
# 19 :
#
# 20 :
#
# 21 : function_exercises.calculate_tip(0.2, 50)
#
# 22 :
#
# 23 :
#
# 24 : # -- use from to import the function directly
#
# 25 :
#
# 26 : # In[3]:
#
# 27 :
#
# 28 :
#
# 29 : from function_exercises import apply_discount
#
# 30 :
#
# 31 :
#
# 32 : # In[4]:
#
# 33 :
#
# 34 :
#
# 35 : apply_discount(4697, 0.3)
#
# 36 :
#
# 37 :
#
# 38 : # -- use from and give the function a different name
#
# 39 :
#
# 40 : # In[5]:
#
# 41 :
#
# 42 :
#
# 43 : from function_exercises import handle_commas as commas_are_bad
#
# 44 :
#
# 45 :
#
# 46 : # In[6]:
#
# 47 :
#
# 48 :
#
# 49 : commas_are_bad('2,935,023')
#
# 50 :
#
# 51 :
#
# 52 : # For the following exercises, read about and use the itertools module from the standard library to help you solve the problem.
#
# 53 : #
#
# 54 : # 1. How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# 55 :
#
# 56 : # In[12]:
#
# 57 :
#
# 58 :
#
# 59 : from itertools import product
#
# 60 :
#
# 61 : list(product('abc', '123'))
#
# 62 :
#
# 63 :
#
# 64 : # In[13]:
#
# 65 :
#
# 66 :
#
# 67 : len(list(product('abc', '123')))
#
# 68 :
#
# 69 :
#
# 70 : # 2. How many different ways can you combine two of the letters from "abcd"?
#
# 71 :
#
# 72 : # In[169]:
#
# 73 :
#
# 74 :
#
# 75 : from itertools import combinations
#
# 76 :
#
# 77 : list(combinations('abcd', 2))
#
# 78 :
#
# 79 :
#
# 80 : # In[170]:
#
# 81 :
#
# 82 :
#
# 83 : len(list(combinations('abcd', 2)))
#
# 84 :
#
# 85 :
#
# 86 : # Save this file as profiles.json inside of your exercises directory. Use the load function from the json module to open this file, it will produce a list of dictionaries.
#
# 87 :
#
# 88 : # In[173]:
#
# 89 :
#
# 90 :
#
# 91 : from json import load
#
# 92 :
#
# 93 :
#
# 94 : # In[25]:
#
# 95 :
#
# 96 :
#
# 97 : profiles = load(open("profiles.json"))
#
# 98 :
#
# 99 :
#
# 100 : # In[27]:
#
# 101 :
#
# 102 :
#
# 103 : profiles
#
# 104 :
#
# 105 :
#
# 106 : # In[178]:
#
# 107 :
#
# 108 :
#
# 109 : profiles[0]
#
# 110 :
#
# 111 :
#
# 112 : # In[177]:
#
# 113 :
#
# 114 :
#
# 115 : profiles[0].keys()
#
# 116 :
#
# 117 :
#
# 118 : # In[180]:
#
# 119 :
#
# 120 :
#
# 121 : # shows the first 4 values with 'in profiles[:4]'
#
# 122 : [profile['balance'] for profile in profiles[:4]]
#
# 123 :
#
# 124 :
#
# 125 : # In[181]:
#
# 126 :
#
# 127 :
#
# 128 : from pprint import pprint
#
# 129 :
#
# 130 : pprint(profiles)
#
# 131 :
#
# 132 :
#
# 133 : # Using this data, write some code that calculates and outputs the following information:
#
# 134 : #
#
# 135 : # Total number of users
#
# 136 :
#
# 137 : # In[28]:
#
# 138 :
#
# 139 :
#
# 140 : len(profiles)
#
# 141 :
#
# 142 :
#
# 143 : # Number of active users
#
# 144 :
#
# 145 : # In[182]:
#
# 146 :
#
# 147 :
#
# 148 : len([profile for profile in profiles if profile['isActive']])
#
# 149 :
#
# 150 :
#
# 151 : # Number of inactive users
#
# 152 :
#
# 153 : # In[183]:
#
# 154 :
#
# 155 :
#
# 156 : len([profile for profile in profiles if not profile['isActive']])
#
# 157 :
#
# 158 :
#
# 159 : # Grand total of balances for all users
#
# 160 :
#
# 161 : # In[63]:
#
# 162 :
#
# 163 :
#
# 164 : profile_balances = [profile['balance'] for profile in profiles]
#
# 165 :
#
# 166 : profile_balances
#
# 167 :
#
# 168 :
#
# 169 : # In[185]:
#
# 170 :
#
# 171 :
#
# 172 : def dollars_to_float(num):
#
# 173 :     return float(num.replace(',','').replace('$',''))
#
# 174 :
#
# 175 :
#
# 176 : # In[186]:
#
# 177 :
#
# 178 :
#
# 179 : dollars_to_float('$2,940.24')
#
# 180 :
#
# 181 :
#
# 182 : # In[188]:
#
# 183 :
#
# 184 :
#
# 185 : # Solution from class
#
# 186 : [dollars_to_float(profile['balance']) for profile in profiles]
#
# 187 :
#
# 188 :
#
# 189 : # In[168]:
#
# 190 :
#
# 191 :
#
# 192 : newlist = []
#
# 193 :
#
# 194 : for profile in profile_balances:
#
# 195 :     newlist.append(dollars_to_float(profile))
#
# 196 :
#
# 197 : newlist
#
# 198 :
#
# 199 :
#
# 200 : # In[70]:
#
# 201 :
#
# 202 :
#
# 203 : sum(newlist)
#
# 204 :
#
# 205 :
#
# 206 : # In[ ]:
#
# 207 :
#
# 208 :
#
# 209 : Average balance per user
#
# 210 :
#
# 211 :
#
# 212 : # In[74]:
#
# 213 :
#
# 214 :
#
# 215 : sum(newlist) / len(newlist)
#
# 216 :
#
# 217 :
#
# 218 : # User with the lowest balance
#
# 219 :
#
# 220 : # In[89]:
#
# 221 :
#
# 222 :
#
# 223 : min(newlist)
#
# 224 :
#
# 225 :
#
# 226 : # In[104]:
#
# 227 :
#
# 228 :
#
# 229 : [x for x in range(len(newlist)) if newlist[x] == min(newlist)]
#
# 230 :
#
# 231 :
#
# 232 : # In[108]:
#
# 233 :
#
# 234 :
#
# 235 : profiles[6]['name'], profiles[6]['balance']
#
# 236 :
#
# 237 :
#
# 238 : # User with the highest balance
#
# 239 :
#
# 240 : # In[109]:
#
# 241 :
#
# 242 :
#
# 243 : max(newlist)
#
# 244 :
#
# 245 :
#
# 246 : # In[110]:
#
# 247 :
#
# 248 :
#
# 249 : [x for x in range(len(newlist)) if newlist[x] == max(newlist)]
#
# 250 :
#
# 251 :
#
# 252 : # In[111]:
#
# 253 :
#
# 254 :
#
# 255 : profiles[3]['name'], profiles[3]['balance']
#
# 256 :
#
# 257 :
#
# 258 : # Most common favorite fruit
#
# 259 :
#
# 260 : # In[122]:
#
# 261 :
#
# 262 :
#
# 263 : fruitlist = [profile['favoriteFruit'] for profile in profiles]
#
# 264 :
#
# 265 : fruitlist
#
# 266 :
#
# 267 :
#
# 268 : # In[134]:
#
# 269 :
#
# 270 :
#
# 271 : fruitcount = [fruitlist.count(x) for x in fruitlist]
#
# 272 : fruitcount
#
# 273 :
#
# 274 :
#
# 275 : # In[143]:
#
# 276 :
#
# 277 :
#
# 278 : max(list(zip(fruitcount, fruitlist)))
#
# 279 :
#
# 280 :
#
# 281 : # Least most common favorite fruit
#
# 282 :
#
# 283 : # In[144]:
#
# 284 :
#
# 285 :
#
# 286 : min(list(zip(fruitcount, fruitlist)))
#
# 287 :
#
# 288 :
#
# 289 : # Total number of unread messages for all users
#
# 290 :
#
# 291 : # In[148]:
#
# 292 :
#
# 293 :
#
# 294 : greetinglist = [profile['greeting'] for profile in profiles]
#
# 295 :
#
# 296 : greetinglist
#
# 297 :
#
# 298 :
#
# 299 : # In[161]:
#
# 300 :
#
# 301 :
#
# 302 : def get_digits(string):
#
# 303 :     new_string = ''
#
# 304 :     for s in string:
#
# 305 :         if s.isdigit():
#
# 306 :             new_string += s
#
# 307 :     return new_string
#
# 308 :
#
# 309 :
#
# 310 : # In[162]:
#
# 311 :
#
# 312 :
#
# 313 : num_messages = []
#
# 314 :
#
# 315 : for x in message_list:
#
# 316 :     num_messages.append(int(get_digits(x)))
#
# 317 :
#
# 318 : num_messages
#
# 319 :
#
# 320 :
#
# 321 : # In[163]:
#
# 322 :
#
# 323 :
#
# 324 : sum(num_messages)
#
# 325 :
#
# 326 :
#
# 327 : # In[193]:
#
# 328 :
#
# 329 :
#
# 330 : # Solutions from class:
#
# 331 :
#
# 332 : def get_n_unread_messages(profile):
#
# 333 :         greeting = profile['greeting']
#
# 334 :         start_index = greeting.index('have ') + 5
#
# 335 :         end_index = greeting.index(' unread')
#
# 336 :         return int(greeting[start_index:end_index])
#
# 337 :
#
# 338 :
#
# 339 : # In[195]:
#
# 340 :
#
# 341 :
#
# 342 : sum([get_n_unread_messages(profile) for profile in profiles])
#
# 343 :
#
# 344 :
#
# 345 : # In[200]:
#
# 346 :
#
# 347 :
#
# 348 : profile = profiles[0]
#
# 349 : greeting = profile['greeting']
#
# 350 :
#
# 351 : int(''.join([c for c in greeting if c. isdigit()]))
#
# 352 :
#
# 353 :
#
# 354 : # In[ ]:
#
# 355 :
#
# 356 :
#
# 357 :
#
# 358 :

# %% [markdown]
# Print out every line in the file

# %%
print(contents)
# Out:
# #!/usr/bin/env python
# # coding: utf-8
#
# # 1. Import and test 3 of the functions from your functions exercise file.
# #
# # -- Your functions exercise are not currently in a file with a name that can be easily imported. Copy your functions exercise file and name the copy functions_exercises.py.
# #
# # -- Import each function in a different way:
# #
# # -- import the module and refer to the function with the . syntax
#
# # In[1]:
#
#
# import function_exercises
#
#
# # In[2]:
#
#
# function_exercises.calculate_tip(0.2, 50)
#
#
# # -- use from to import the function directly
#
# # In[3]:
#
#
# from function_exercises import apply_discount
#
#
# # In[4]:
#
#
# apply_discount(4697, 0.3)
#
#
# # -- use from and give the function a different name
#
# # In[5]:
#
#
# from function_exercises import handle_commas as commas_are_bad
#
#
# # In[6]:
#
#
# commas_are_bad('2,935,023')
#
#
# # For the following exercises, read about and use the itertools module from the standard library to help you solve the problem.
# #
# # 1. How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# # In[12]:
#
#
# from itertools import product
#
# list(product('abc', '123'))
#
#
# # In[13]:
#
#
# len(list(product('abc', '123')))
#
#
# # 2. How many different ways can you combine two of the letters from "abcd"?
#
# # In[169]:
#
#
# from itertools import combinations
#
# list(combinations('abcd', 2))
#
#
# # In[170]:
#
#
# len(list(combinations('abcd', 2)))
#
#
# # Save this file as profiles.json inside of your exercises directory. Use the load function from the json module to open this file, it will produce a list of dictionaries.
#
# # In[173]:
#
#
# from json import load
#
#
# # In[25]:
#
#
# profiles = load(open("profiles.json"))
#
#
# # In[27]:
#
#
# profiles
#
#
# # In[178]:
#
#
# profiles[0]
#
#
# # In[177]:
#
#
# profiles[0].keys()
#
#
# # In[180]:
#
#
# # shows the first 4 values with 'in profiles[:4]'
# [profile['balance'] for profile in profiles[:4]]
#
#
# # In[181]:
#
#
# from pprint import pprint
#
# pprint(profiles)
#
#
# # Using this data, write some code that calculates and outputs the following information:
# #
# # Total number of users
#
# # In[28]:
#
#
# len(profiles)
#
#
# # Number of active users
#
# # In[182]:
#
#
# len([profile for profile in profiles if profile['isActive']])
#
#
# # Number of inactive users
#
# # In[183]:
#
#
# len([profile for profile in profiles if not profile['isActive']])
#
#
# # Grand total of balances for all users
#
# # In[63]:
#
#
# profile_balances = [profile['balance'] for profile in profiles]
#
# profile_balances
#
#
# # In[185]:
#
#
# def dollars_to_float(num):
#     return float(num.replace(',','').replace('$',''))
#
#
# # In[186]:
#
#
# dollars_to_float('$2,940.24')
#
#
# # In[188]:
#
#
# # Solution from class
# [dollars_to_float(profile['balance']) for profile in profiles]
#
#
# # In[168]:
#
#
# newlist = []
#
# for profile in profile_balances:
#     newlist.append(dollars_to_float(profile))
#
# newlist
#
#
# # In[70]:
#
#
# sum(newlist)
#
#
# # In[ ]:
#
#
# Average balance per user
#
#
# # In[74]:
#
#
# sum(newlist) / len(newlist)
#
#
# # User with the lowest balance
#
# # In[89]:
#
#
# min(newlist)
#
#
# # In[104]:
#
#
# [x for x in range(len(newlist)) if newlist[x] == min(newlist)]
#
#
# # In[108]:
#
#
# profiles[6]['name'], profiles[6]['balance']
#
#
# # User with the highest balance
#
# # In[109]:
#
#
# max(newlist)
#
#
# # In[110]:
#
#
# [x for x in range(len(newlist)) if newlist[x] == max(newlist)]
#
#
# # In[111]:
#
#
# profiles[3]['name'], profiles[3]['balance']
#
#
# # Most common favorite fruit
#
# # In[122]:
#
#
# fruitlist = [profile['favoriteFruit'] for profile in profiles]
#
# fruitlist
#
#
# # In[134]:
#
#
# fruitcount = [fruitlist.count(x) for x in fruitlist]
# fruitcount
#
#
# # In[143]:
#
#
# max(list(zip(fruitcount, fruitlist)))
#
#
# # Least most common favorite fruit
#
# # In[144]:
#
#
# min(list(zip(fruitcount, fruitlist)))
#
#
# # Total number of unread messages for all users
#
# # In[148]:
#
#
# greetinglist = [profile['greeting'] for profile in profiles]
#
# greetinglist
#
#
# # In[161]:
#
#
# def get_digits(string):
#     new_string = ''
#     for s in string:
#         if s.isdigit():
#             new_string += s
#     return new_string
#
#
# # In[162]:
#
#
# num_messages = []
#
# for x in message_list:
#     num_messages.append(int(get_digits(x)))
#
# num_messages
#
#
# # In[163]:
#
#
# sum(num_messages)
#
#
# # In[193]:
#
#
# # Solutions from class:
#
# def get_n_unread_messages(profile):
#         greeting = profile['greeting']
#         start_index = greeting.index('have ') + 5
#         end_index = greeting.index(' unread')
#         return int(greeting[start_index:end_index])
#
#
# # In[195]:
#
#
# sum([get_n_unread_messages(profile) for profile in profiles])
#
#
# # In[200]:
#
#
# profile = profiles[0]
# greeting = profile['greeting']
#
# int(''.join([c for c in greeting if c. isdigit()]))
#
#
# # In[ ]:

# %%
with open('4.6_import_exercises.py') as f:
    print(f.readlines())
# Out:
# ['#!/usr/bin/env python\n', '# coding: utf-8\n', '\n', '# 1. Import and test 3 of the functions from your functions exercise file.\n', '# \n', '# -- Your functions exercise are not currently in a file with a name that can be easily imported. Copy your functions exercise file and name the copy functions_exercises.py.\n', '# \n', '# -- Import each function in a different way:\n', '# \n', '# -- import the module and refer to the function with the . syntax\n', '\n', '# In[1]:\n', '\n', '\n', 'import function_exercises\n', '\n', '\n', '# In[2]:\n', '\n', '\n', 'function_exercises.calculate_tip(0.2, 50)\n', '\n', '\n', '# -- use from to import the function directly\n', '\n', '# In[3]:\n', '\n', '\n', 'from function_exercises import apply_discount\n', '\n', '\n', '# In[4]:\n', '\n', '\n', 'apply_discount(4697, 0.3)\n', '\n', '\n', '# -- use from and give the function a different name\n', '\n', '# In[5]:\n', '\n', '\n', 'from function_exercises import handle_commas as commas_are_bad\n', '\n', '\n', '# In[6]:\n', '\n', '\n', "commas_are_bad('2,935,023')\n", '\n', '\n', '# For the following exercises, read about and use the itertools module from the standard library to help you solve the problem.\n', '# \n', '# 1. How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?\n', '\n', '# In[12]:\n', '\n', '\n', 'from itertools import product\n', '\n', "list(product('abc', '123'))\n", '\n', '\n', '# In[13]:\n', '\n', '\n', "len(list(product('abc', '123')))\n", '\n', '\n', '# 2. How many different ways can you combine two of the letters from "abcd"?\n', '\n', '# In[169]:\n', '\n', '\n', 'from itertools import combinations\n', '\n', "list(combinations('abcd', 2))\n", '\n', '\n', '# In[170]:\n', '\n', '\n', "len(list(combinations('abcd', 2)))\n", '\n', '\n', '# Save this file as profiles.json inside of your exercises directory. Use the load function from the json module to open this file, it will produce a list of dictionaries. \n', '\n', '# In[173]:\n', '\n', '\n', 'from json import load\n', '\n', '\n', '# In[25]:\n', '\n', '\n', 'profiles = load(open("profiles.json"))\n', '\n', '\n', '# In[27]:\n', '\n', '\n', 'profiles\n', '\n', '\n', '# In[178]:\n', '\n', '\n', 'profiles[0]\n', '\n', '\n', '# In[177]:\n', '\n', '\n', 'profiles[0].keys()\n', '\n', '\n', '# In[180]:\n', '\n', '\n', "# shows the first 4 values with 'in profiles[:4]'\n", "[profile['balance'] for profile in profiles[:4]]\n", '\n', '\n', '# In[181]:\n', '\n', '\n', 'from pprint import pprint\n', '\n', 'pprint(profiles)\n', '\n', '\n', '# Using this data, write some code that calculates and outputs the following information:\n', '# \n', '# Total number of users\n', '\n', '# In[28]:\n', '\n', '\n', 'len(profiles)\n', '\n', '\n', '# Number of active users\n', '\n', '# In[182]:\n', '\n', '\n', "len([profile for profile in profiles if profile['isActive']])\n", '\n', '\n', '# Number of inactive users\n', '\n', '# In[183]:\n', '\n', '\n', "len([profile for profile in profiles if not profile['isActive']])\n", '\n', '\n', '# Grand total of balances for all users\n', '\n', '# In[63]:\n', '\n', '\n', "profile_balances = [profile['balance'] for profile in profiles]\n", '\n', 'profile_balances\n', '\n', '\n', '# In[185]:\n', '\n', '\n', 'def dollars_to_float(num):\n', "    return float(num.replace(',','').replace('$',''))\n", '\n', '\n', '# In[186]:\n', '\n', '\n', "dollars_to_float('$2,940.24')\n", '\n', '\n', '# In[188]:\n', '\n', '\n', '# Solution from class\n', "[dollars_to_float(profile['balance']) for profile in profiles]\n", '\n', '\n', '# In[168]:\n', '\n', '\n', 'newlist = []\n', '\n', 'for profile in profile_balances:\n', '    newlist.append(dollars_to_float(profile))\n', '    \n', 'newlist\n', '\n', '\n', '# In[70]:\n', '\n', '\n', 'sum(newlist)\n', '\n', '\n', '# In[ ]:\n', '\n', '\n', 'Average balance per user\n', '\n', '\n', '# In[74]:\n', '\n', '\n', 'sum(newlist) / len(newlist)\n', '\n', '\n', '# User with the lowest balance\n', '\n', '# In[8 ...

# %% [markdown]
# Print out every line in the file, but add a line numbers

# %%
for i,x in enumerate(contents.split('\n'), 1):
    print(i,x)
# Out:
# 1 #!/usr/bin/env python
# 2 # coding: utf-8
# 3
# 4 # 1. Import and test 3 of the functions from your functions exercise file.
# 5 #
# 6 # -- Your functions exercise are not currently in a file with a name that can be easily imported. Copy your functions exercise file and name the copy functions_exercises.py.
# 7 #
# 8 # -- Import each function in a different way:
# 9 #
# 10 # -- import the module and refer to the function with the . syntax
# 11
# 12 # In[1]:
# 13
# 14
# 15 import function_exercises
# 16
# 17
# 18 # In[2]:
# 19
# 20
# 21 function_exercises.calculate_tip(0.2, 50)
# 22
# 23
# 24 # -- use from to import the function directly
# 25
# 26 # In[3]:
# 27
# 28
# 29 from function_exercises import apply_discount
# 30
# 31
# 32 # In[4]:
# 33
# 34
# 35 apply_discount(4697, 0.3)
# 36
# 37
# 38 # -- use from and give the function a different name
# 39
# 40 # In[5]:
# 41
# 42
# 43 from function_exercises import handle_commas as commas_are_bad
# 44
# 45
# 46 # In[6]:
# 47
# 48
# 49 commas_are_bad('2,935,023')
# 50
# 51
# 52 # For the following exercises, read about and use the itertools module from the standard library to help you solve the problem.
# 53 #
# 54 # 1. How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
# 55
# 56 # In[12]:
# 57
# 58
# 59 from itertools import product
# 60
# 61 list(product('abc', '123'))
# 62
# 63
# 64 # In[13]:
# 65
# 66
# 67 len(list(product('abc', '123')))
# 68
# 69
# 70 # 2. How many different ways can you combine two of the letters from "abcd"?
# 71
# 72 # In[169]:
# 73
# 74
# 75 from itertools import combinations
# 76
# 77 list(combinations('abcd', 2))
# 78
# 79
# 80 # In[170]:
# 81
# 82
# 83 len(list(combinations('abcd', 2)))
# 84
# 85
# 86 # Save this file as profiles.json inside of your exercises directory. Use the load function from the json module to open this file, it will produce a list of dictionaries.
# 87
# 88 # In[173]:
# 89
# 90
# 91 from json import load
# 92
# 93
# 94 # In[25]:
# 95
# 96
# 97 profiles = load(open("profiles.json"))
# 98
# 99
# 100 # In[27]:
# 101
# 102
# 103 profiles
# 104
# 105
# 106 # In[178]:
# 107
# 108
# 109 profiles[0]
# 110
# 111
# 112 # In[177]:
# 113
# 114
# 115 profiles[0].keys()
# 116
# 117
# 118 # In[180]:
# 119
# 120
# 121 # shows the first 4 values with 'in profiles[:4]'
# 122 [profile['balance'] for profile in profiles[:4]]
# 123
# 124
# 125 # In[181]:
# 126
# 127
# 128 from pprint import pprint
# 129
# 130 pprint(profiles)
# 131
# 132
# 133 # Using this data, write some code that calculates and outputs the following information:
# 134 #
# 135 # Total number of users
# 136
# 137 # In[28]:
# 138
# 139
# 140 len(profiles)
# 141
# 142
# 143 # Number of active users
# 144
# 145 # In[182]:
# 146
# 147
# 148 len([profile for profile in profiles if profile['isActive']])
# 149
# 150
# 151 # Number of inactive users
# 152
# 153 # In[183]:
# 154
# 155
# 156 len([profile for profile in profiles if not profile['isActive']])
# 157
# 158
# 159 # Grand total of balances for all users
# 160
# 161 # In[63]:
# 162
# 163
# 164 profile_balances = [profile['balance'] for profile in profiles]
# 165
# 166 profile_balances
# 167
# 168
# 169 # In[185]:
# 170
# 171
# 172 def dollars_to_float(num):
# 173     return float(num.replace(',','').replace('$',''))
# 174
# 175
# 176 # In[186]:
# 177
# 178
# 179 dollars_to_float('$2,940.24')
# 180
# 181
# 182 # In[188]:
# 183
# 184
# 185 # Solution from class
# 186 [dollars_to_float(profile['balance']) for profile in profiles]
# 187
# 188
# 189 # In[168]:
# 190
# 191
# 192 newlist = []
# 193
# 194 for profile in profile_balances:
# 195     newlist.append(dollars_to_float(profile))
# 196
# 197 newlist
# 198
# 199
# 200 # In[70]:
# 201
# 202
# 203 sum(newlist)
# 204
# 205
# 206 # In[ ]:
# 207
# 208
# 209 Average balance per user
# 210
# 211
# 212 # In[74]:
# 213
# 214
# 215 sum(newlist) / len(newlist)
# 216
# 217
# 218 # User with the lowest balance
# 219
# 220 # In[89]:
# 221
# 222
# 223 min(newlist)
# 224
# 225
# 226 # In[104]:
# 227
# 228
# 229 [x for x in range(len(newlist)) if newlist[x] == min(newlist)]
# 230
# 231
# 232 # In[108]:
# 233
# 234
# 235 profiles[6]['name'], profiles[6]['balance']
# 236
# 237
# 238 # User with the highest balance
# 239
# 240 # In[109]:
# 241
# 242
# 243 max(newlist)
# 244
# 245
# 246 # In[110]:
# 247
# 248
# 249 [x for x in range(len(newlist)) if newlist[x] == max(newlist)]
# 250
# 251
# 252 # In[111]:
# 253
# 254
# 255 profiles[3]['name'], profiles[3]['balance']
# 256
# 257
# 258 # Most common favorite fruit
# 259
# 260 # In[122]:
# 261
# 262
# 263 fruitlist = [profile['favoriteFruit'] for profile in profiles]
# 264
# 265 fruitlist
# 266
# 267
# 268 # In[134]:
# 269
# 270
# 271 fruitcount = [fruitlist.count(x) for x in fruitlist]
# 272 fruitcount
# 273
# 274
# 275 # In[143]:
# 276
# 277
# 278 max(list(zip(fruitcount, fruitlist)))
# 279
# 280
# 281 # Least most common favorite fruit
# 282
# 283 # In[144]:
# 284
# 285
# 286 min(list(zip(fruitcount, fruitlist)))
# 287
# 288
# 289 # Total number of unread messages for all users
# 290
# 291 # In[148]:
# 292
# 293
# 294 greetinglist = [profile['greeting'] for profile in profiles]
# 295
# 296 greetinglist
# 297
# 298
# 299 # In[161]:
# 300
# 301
# 302 def get_digits(string):
# 303     new_string = ''
# 304     for s in string:
# 305         if s.isdigit():
# 306             new_string += s
# 307     return new_string
# 308
# 309
# 310 # In[162]:
# 311
# 312
# 313 num_messages = []
# 314
# 315 for x in message_list:
# 316     num_messages.append(int(get_digits(x)))
# 317
# 318 num_messages
# 319
# 320
# 321 # In[163]:
# 322
# 323
# 324 sum(num_messages)
# 325
# 326
# 327 # In[193]:
# 328
# 329
# 330 # Solutions from class:
# 331
# 332 def get_n_unread_messages(profile):
# 333         greeting = profile['greeting']
# 334         start_index = greeting.index('have ') + 5
# 335         end_index = greeting.index(' unread')
# 336         return int(greeting[start_index:end_index])
# 337
# 338
# 339 # In[195]:
# 340
# 341
# 342 sum([get_n_unread_messages(profile) for profile in profiles])
# 343
# 344
# 345 # In[200]:
# 346
# 347
# 348 profile = profiles[0]
# 349 greeting = profile['greeting']
# 350
# 351 int(''.join([c for c in greeting if c. isdigit()]))
# 352
# 353
# 354 # In[ ]:
# 355
# 356
# 357
# 358
# 359

# %% [markdown]
# Write some python code to create a grocery list.
#
# Create a variable named grocery_list. It should be a list, and the elements in the list should be a least 3 things that you need to buy from the grocery store.

# %%
grocery_list = ['milk', 'cheese', 'coffee']

# %% [markdown]
# Create a function named make_grocery_list. When run, this function should write the contents of the grocery_list variable to a file named my_grocery_list.txt.

# %%
def make_grocery_list(groceries):
    with open('my_grocery_list.txt', 'w') as f:
        for grocery in groceries:
            f.write(grocery + '\n')

make_grocery_list(grocery_list)

# %% [markdown]
# Create a function named show_grocery_list. When run, it should read the items from the text file and show each item on the grocery list.

# %%
def show_grocery_list():
    with open('my_grocery_list.txt') as f:
        print(f.read())

# %%
show_grocery_list()
# Out:
# milk
# cheese
# coffee

# %% [markdown]
# Create a function named buy_item. It should accept the name of an item on the grocery list, and remove that item from the list.

# %%
def buy_item(item):
    with open('my_grocery_list.txt', 'w') as f:
        for x in grocery_list:
            if x != item:
                f.writelines(x + '\n')

# %%
buy_item('milk')

# %%
show_grocery_list()
# Out:
# cheese
# coffee
